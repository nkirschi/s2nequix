# %%
from matplotlib.ticker import LogFormatter

import matplotlib.pyplot as plt
import pandas as pd

# %%
energy_df = pd.read_csv("results/3bpa_alphascan_energy.csv")
forces_df = pd.read_csv("results/3bpa_alphascan_forces.csv")
lr_df = pd.read_csv("results/3bpa_alphascan_lr.csv")

# %%
run_names = {
    0.1: "lv2prrgk-112",
    1: "6gk9uial-111",
    10: "4ojp66b1-114",
    100: "k0vm6p66-114",
    1000: "bzebif6e-113",
}

# %%
def plot_metric(df, metric_name, ylabel, ymin=None,ymax=None, yfactor=1, logscale=False):
    for alpha, run_name in run_names.items():
        plt.plot(df["Step"], yfactor * df[f"{run_name} - {metric_name}"], label=f"$\\alpha$={alpha}", linewidth=0.8)
    if logscale:
        plt.yscale("log")
        class SmartDecimalFormatter(LogFormatter):
            def _num_to_string(self, x, vmin, vmax):
                return f"{x:g}"
        formatter = SmartDecimalFormatter()
        plt.gca().yaxis.set_major_formatter(formatter)
        plt.gca().yaxis.set_minor_formatter(formatter)
    if ymax is not None:
        plt.ylim(ymin, ymax)
    plt.xlabel("step [#batches]")
    plt.ylabel(ylabel)
    plt.ticklabel_format(axis='x', style='sci', scilimits=(0,6))
    plt.grid(True, which="both", ls="--", linewidth=0.5)
    plt.legend()

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 3, 1)
plot_metric(energy_df, "val/energy_mae_per_atom", "Energy MAE [meV/atom]", ymin=0.07, ymax=1, yfactor=1000, logscale=True)
plt.subplot(1, 3, 2)
plot_metric(forces_df, "val/force_mae", "Forces MAE [meV/Å]", ymin=9, ymax=25, yfactor=1000, logscale=True)
plt.subplot(1, 3, 3)
plot_metric(lr_df, "learning_rate", "Learning Rate")
plt.tight_layout()
plt.savefig("plots/3bpa_alphascan.pdf", dpi=300)
plt.savefig("plots/3bpa_alphascan.png", dpi=300)
plt.show()
